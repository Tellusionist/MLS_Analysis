# %% [markdown]
# # Exploratory Analysis of the MLS

# %%
import requests
import json
import pandas as pd
from time import sleep
from datetime import datetime

# %%
pd.set_option('display.max_columns', 40)

# %%
amer_soccer_mls_url = "https://app.americansocceranalysis.com/api/v1/mls/"
fotmob_url = 'https://www.fotmob.com'

# %%
url = amer_soccer_mls_url + 'teams'
r = requests.get(url)

# %%
teams = pd.read_json(json.dumps(r.json()))
teams.head()
# Out:
#       team_id               team_name team_short_name team_abbreviation
# 0  0KPqjA456v    San Jose Earthquakes        San Jose               SJE
# 1  19vQ2095K6  New England Revolution     New England               NER
# 2  4wM42l4qjB              Chivas USA          Chivas               CHV
# 3  9z5k7Yg5A3      Philadelphia Union    Philadelphia               PHI
# 4  a2lqR4JMr0          Real Salt Lake       Salt Lake               RSL

# %%
# build list of teams to iterate through
team_ids = teams['team_id'].unique()

# %%
# extract all matches and combine into a single dataframe
url = amer_soccer_mls_url + 'games'
all_matches = pd.DataFrame()
for team_id in team_ids:
    team_name = teams.team_name.loc[teams.team_id==team_id].item()
    print("Pulling matches for:", team_name)
    params = {'team_id':team_id}
    r = requests.get(url,params)
    tmp_df = pd.read_json(json.dumps(r.json()), convert_dates=False) # has issues with some results
    tmp_df['source_team_id'] = team_id
    all_matches = all_matches.append(tmp_df)
    sleep(0.5)
print("Finished! Found",len(all_matches),"matches.")
# Out:
# Pulling matches for: San Jose Earthquakes
# Pulling matches for: New England Revolution
# Pulling matches for: Chivas USA
# Pulling matches for: Philadelphia Union
# Pulling matches for: Real Salt Lake
# Pulling matches for: New York Red Bulls
# Pulling matches for: CF Montréal
# Pulling matches for: D.C. United
# Pulling matches for: Los Angeles FC
# Pulling matches for: Austin FC
# Pulling matches for: Seattle Sounders FC
# Pulling matches for: Orlando City SC
# Pulling matches for: LA Galaxy
# Pulling matches for: Atlanta United FC
# Pulling matches for: Toronto FC
# Pulling matches for: Minnesota United FC
# Pulling matches for: Vancouver Whitecaps FC
# Pulling matches for: FC Dallas
# Pulling matches for: Columbus Crew
# Pulling matches for: Charlotte FC
# Pulling matches for: FC Cincinnati
# Pulling matches for: Colorado Rapids
# Pulling matches for: New York City FC
# Pulling matches for: Nashville SC
# Pulling matches for: Portland Timbers FC
# Pulling matches for: Chicago Fire FC
# Pulling matches for: Houston Dynamo FC
# Pulling matches for: Sporting Kansas City
# Pulling matches for: Inter Miami CF
# Finished! Found 6892 matches.

# %%
# save locally
all_matches.to_csv('MLS_All_Matches.csv',header=True)

# %%
# take a peek
all_matches.head()
# Out:
#       game_id            date_time_utc  home_score  away_score home_team_id  \
# 0  OlMloN20QL  2022-03-13 00:30:00 UTC           2           0   9z5k7Yg5A3
# 1  wvq9RAPwQW  2022-03-05 22:30:00 UTC           3           3   0KPqjA456v
# 2  4JMA7YK1qK  2022-02-26 23:00:00 UTC           1           3   0KPqjA456v
# 3  OlMlaRwy5L  2021-11-07 23:00:00 UTC           1           1   0KPqjA456v
# 4  eVq3J8Vn5W  2021-10-30 19:30:00 UTC           3           4   a2lqR4JMr0
#
#   away_team_id  referee_id  stadium_id home_manager_id away_manager_id  \
# 0   0KPqjA456v  2lqRymD5r0  NWMW8ZN5lz      0Oq6vPrq6D      2vQ10jwqrA
# 1   mvzqoLZQap  wvq9vKlQWn  Vj58W84M8n      2vQ10jwqrA      NPqxkDY59d
# 2   a2lqRX2Mr0  Pk5LRpDQOW  Vj58W84M8n      2vQ10jwqrA      9z5kKNb5A3
# 3   mKAqBBmqbg  2lqRymD5r0  Vj58W84M8n      2vQ10jwqrA      2vQ1m6bQrA
# 4   0KPqjA456v  4JMAYlPMKg  e7MzlRjqr0      4wM4vOAqjB      2vQ10jwqrA
#
#    expanded_minutes  season_name  matchday  attendance  knockout_game  \
# 0               104         2022         3           0          False
# 1               103         2022         2       12888          False
# 2               101         2022         1       16146          False
# 3                99         2021        35           0          False
# 4                99         2021        34       15553          False
#
#           last_updated_utc  extra_time  penalties  home_penalties  \
# 0  2022-03-13 03:03:16 UTC         NaN        NaN             NaN
# 1  2022-03-09 14:38:55 UTC         NaN        NaN             NaN
# 2  2022-03-02 08:49:02 UTC         NaN        NaN             NaN
# 3  2021-11-11 07:49:35 UTC         NaN        NaN             NaN
# 4  2021-11-02 08:56:51 UTC         NaN        NaN             NaN
#
#    away_penalties source_team_id
# 0             NaN     0KPqjA456v
# 1             NaN     0KPqjA456v
# 2             NaN     0KPqjA456v
# 3             NaN     0KPqjA456v
# 4             NaN     0KPqjA456v

# %%
# convert the dates
all_matches['date_time_utc'] = pd.to_datetime(all_matches['date_time_utc'] , infer_datetime_format=True)  
# recognize it as UTC
all_matches['date_time_utc'] = all_matches['date_time_utc'].dt.tz_localize('UTC')
# convert to PST to match timezone for future processing
all_matches['date_time_est'] = all_matches['date_time_utc'].dt.tz_convert('US/Pacific')
# format the date into string for future processing
all_matches['date_est_formatted'] = all_matches['date_time_est'].dt.strftime("%Y%m%d")

# %%
# checking out the data goes
match_dates = all_matches.date_est_formatted.unique()
match_dates.sort()
print("Earliest match:", min(match_dates))
print("Latest match:", max(match_dates))
print("Unique dates:", len(match_dates))
# Out:
# Earliest match: 20130302
# Latest match: 20220312
# Unique dates: 952

# %%
# save referee data
url = amer_soccer_mls_url + 'referees'
r = requests.get(url)
referees = pd.read_json(json.dumps(r.json()))
referees.to_csv('MLS_Referees.csv',header=True)

# %%
# save team data
url = amer_soccer_mls_url + 'teams'
r = requests.get(url)
teams = pd.read_json(json.dumps(r.json()))
teams.to_csv('MLS_teams.csv',header=True)

# %%
# save manager data
url = amer_soccer_mls_url + 'managers'
r = requests.get(url)
managers = pd.read_json(json.dumps(r.json()))
managers.to_csv('MLS_managers.csv',header=True)

# %%
# save stadium data
url = amer_soccer_mls_url + 'stadia'
r = requests.get(url)
stadiums = pd.read_json(json.dumps(r.json()))
stadiums.to_csv('MLS_managers.csv',header=True)

# %% [markdown]
# ### Fotmob seems to have an API
# https://github.com/bgrnwd/fotmob/blob/main/docs/api.md
#
# https://www.fotmob.com/

# %%
len(match_dates_beyond_2015)
# Out:
# 733

# %%
# Fotmob doesnt have data prior to 2015, so we will make a new list for >2015
match_dates_beyond_2015 = match_dates[match_dates > '20150000']
Fotmob_matchesby_date_url = fotmob_url + '/matches?date='
fotmob_matches = pd.DataFrame()
current_query = 0
total_queries = len(match_dates_beyond_2015)
for match_day in match_dates_beyond_2015:
    # get that day's matches
    current_query +=1
    print('Working on:',match_day, end=' | ')
    url = Fotmob_matchesby_date_url + match_day
    r = requests.get(url)
    
    # Extact MLS matches only, the primary ID = 130. Swap this out for other leagues
    # Need to check which result is MLS using primary ID 130
    league_cnt = len(r.json()['leagues'])
    i = 0
    for i in range(league_cnt):
        if r.json()['leagues'][i]['primaryId'] == 130:
            # i will retain the proper league ID
            break
    
    # load MLS matches from that day
    tmp_matches = pd.json_normalize(r.json()['leagues'][0]['matches'])
    print(len(tmp_matches),'matches found | ',"{:.1%}".format(current_query / total_queries),'complete')
    fotmob_matches = fotmob_matches.append(tmp_matches)
    sleep(0.15) # just in case there are rate limits
    
print('Total Matches:', len(fotmob_matches))
# Out:
# Working on: 20150306 | 1 matches found |  0.1% complete
# Working on: 20150307 | 6 matches found |  0.3% complete
# Working on: 20150308 | 3 matches found |  0.4% complete
# Working on: 20150313 | 1 matches found |  0.5% complete
# Working on: 20150314 | 5 matches found |  0.7% complete
# Working on: 20150315 | 2 matches found |  0.8% complete
# Working on: 20150321 | 6 matches found |  1.0% complete
# Working on: 20150322 | 1 matches found |  1.1% complete
# Working on: 20150328 | 3 matches found |  1.2% complete
# Working on: 20150329 | 3 matches found |  1.4% complete
# Working on: 20150403 | 1 matches found |  1.5% complete
# Working on: 20150404 | 5 matches found |  1.6% complete
# Working on: 20150405 | 2 matches found |  1.8% complete
# Working on: 20150408 | 1 matches found |  1.9% complete
# Working on: 20150410 | 1 matches found |  2.0% complete
# Working on: 20150411 | 6 matches found |  2.2% complete
# Working on: 20150412 | 2 matches found |  2.3% complete
# Working on: 20150416 | 4 matches found |  2.5% complete
# Working on: 20150417 | 1 matches found |  2.6% complete
# Working on: 20150418 | 6 matches found |  2.7% complete
# Working on: 20150419 | 2 matches found |  2.9% complete
# Working on: 20150424 | 2 matches found |  3.0% complete
# Working on: 20150425 | 4 matches found |  3.1% complete
# Working on: 20150426 | 3 matches found |  3.3% complete
# Working on: 20150429 | 1 matches found |  3.4% complete
# Working on: 20150501 | 2 matches found |  3.5% complete
# Working on: 20150502 | 5 matches found |  3.7% complete
# Working on: 20150503 | 2 matches found |  3.8% complete
# Working on: 20150505 | 1 matches found |  4.0% complete
# Working on: 20150506 | 1 matches found |  4.1% complete
# Working on: 20150508 | 2 matches found |  4.2% complete
# Working on: 20150509 | 6 matches found |  4.4% complete
# Working on: 20150510 | 2 matches found |  4.5% complete
# Working on: 20150513 | 1 matches found |  4.6% complete
# Working on: 20150515 | 2 matches found |  4.8% complete
# Working on: 20150516 | 6 matches found |  4.9% complete
# Working on: 20150517 | 2 matches found |  5.0% complete
# Working on: 20150520 | 1 matches found |  5.2% complete
# Working on: 20150522 | 2 matches found |  5.3% complete
# Working on: 20150523 | 6 matches found |  5.5% complete
# Working on: 20150524 | 1 matches found |  5.6% complete
# Working on: 20150527 | 1 matches found |  5.7% complete
# Working on: 20150529 | 1 matches found |  5.9% complete
# Working on: 20150530 | 7 matches found |  6.0% complete
# Working on: 20150531 | 2 matches found |  6.1% complete
# Working on: 20150603 | 3 matches found |  6.3% complete
# Working on: 20150605 | 1 matches found |  6.4% complete
# Working on: 20150606 | 1 matches found |  6.5% complete
# Working on: 20150607 | 1 matches found |  6.7% complete
# Working on: 20150613 | 3 matches found |  6.8% complete
# Working on: 20150614 | 3 matches found |  7.0% complete
# Working on: 20150619 | 2 matches found |  7.1% complete
# Working on: 20150620 | 2 matches found |  7.2% complete
# Working on: 20150621 | 2 matches found |  7.4% complete
# Working on: 20150624 | 1 matches found |  7.5% complete
# Working on: 20150626 | 1 matches found |  7.6% complete
# Working on: 20150627 | 1 matches found |  7.8% complete
# Working on: 20150628 | 2 matches found |  7.9% complete
# Working on: 20150703 | 1 matches found |  8.0% complete
# Working on: 20150704 | 1 matches found |  8.2% complete
# Working on: 20150705 | 1 matches found |  8.3% complete
# Working on: 20150710 | 1 matches found |  8.5% complete
# Working on: 20150711 | 6 matches found |  8.6% complete
# Working on: 20150712 | 2 matches found |  8.7% complete
# Working on: 20150715 | 5 matches found |  8.9% complete
# Working on: 20150717 | 1 matches found |  9.0% complete
# Working on: 20150718 | 8 matches found |  9.1% complete
# Working on: 20150719 | 1 matches found |  9.3% complete
# Working on: 20150724 | 1 matches found |  9.4% complete
# Working on: 20150725 | 5 matches found |  9.5% complete
# Working on: 20150726 | 3 matches found |  9.7% complete
# Working on: 20150801 | 8 matches found |  9.8% complete
# Working on: 20150802 | 2 matches found |  10.0% complete
# Working on: 20150805 | 11 matches found |  10.1% complete
# Working on: 20150807 | 1 matches found |  10.2% complete
# Working on: 20150808 | 6 matches found |  10.4% complete
# Working on: 20150809 | 2 matches found |  10.5% complete
# Working on: 20150813 | 1 matches found |  10.6% complete
# Working on: 20150814 | 1 matches found |  10.8% complete
# Working on: 20150815 | 5 matches found |  10.9% complete
# Working on: 20150816 | 2 matches found |  11.1% complete
# Working on: 20150819 | 5 matches found |  11.2% complete
# Working on: 20150821 | 1 matches found |  11.3% complete
# Working on: 20150822 | 7 matches found |  11.5% complete
# Working on: 20150823 | 1 matches found |  11.6% complete
# Working on: 20150826 | 5 matches found |  11.7% complete
# Working on: 20150828 | 1 matches found |  11.9% complete
# Working on: 20150829 | 7 matches found |  12.0% complete
# Working on: 20150830 | 2 matches found |  12.1% complete
# Working on: 20150905 | 3 matches found |  12.3% complete
# Working on: 20150906 | 3 matches found |  12.4% complete
# Working on: 20150909 | 2 matches found |  12.6% complete
# Working on: 20150911 | 1 matches found |  12.7% complete
# Working on: 20150912 | 6 matches found |  12.8% complete
# Working on: 20150913 | 2 matches found |  13.0% complete
# Working on: 20150916 | 2 matches found |  13.1% complete
# Working on: 20150918 | 1 matches found |  13.2% complete
# Working on: 20150919 | 7 matches found |  13.4% complete
# Working on: 20150920 | 2 matches found |  13.5% complete
# Working on: 20150923 | 2 matches found |  13.6% complete
# Working on: 20150925 | 1 matches found |  13.8% complete
# Working on: 20150926 | 6 matches found |  13.9% complete
# Working on: 20150927 | 3 matches found |  14.1% complete
# Working on: 20151002 | 1 matches found |  14.2% complete
# Working on: 20151003 | 6 matches found |  14.3% complete
# Working on: 20151004 | 3 matches found |  14.5% complete
# Working on: 20151007 | 4 matches found |  14.6% complete
# Working on: 20151010 | 3 matches found |  14.7% complete
# Working on: 20151014 | 3 matches found |  14.9% complete
# Working on: 20151016 | 2 matches found |  15.0% complete
# Working on: 20151017 | 1 matches found |  15.1% complete
# Working on: 20151018 | 4 matches found |  15.3% complete
# Working on: 20151021 | 2 matches found |  15.4% complete
# Working on: 20151025 | 10 matches found |  15.6% complete
# Working on: 20151028 | 2 matches found |  15.7% complete
# Working on: 20151029 | 2 matches found |  15.8% complete
# Working on: 20151101 | 4 matches found |  16.0% complete
# Working on: 20151108 | 4 matches found |  16.1% complete
# Working on: 20151122 | 2 matches found |  16.2% complete
# Working on: 20151129 | 2 matches found |  16.4% complete
# Working on: 20151206 | 1 matches found |  16.5% complete
# Working on: 20160306 | 10 matches found |  16.6% complete
# Working on: 20160311 | 1 matches found |  16.8% complete
# Working on: 20160312 | 7 matches found |  16.9% complete
# Working on: 20160313 | 2 matches found |  17.1% complete
# Working on: 20160318 | 1 matches found |  17.2% complete
# Working on: 20160319 | 6 matches found |  17.3% complete
# Working on: 20160320 | 3 matches found |  17.5% complete
# Working on: 20160326 | 3 matches found |  17.6% complete
# Working on: 20160401 | 1 matches found |  17.7% complete
# Working on: 20160402 | 7 matches found |  17.9% complete
# Working on: 20160403 | 1 matches found |  18.0% complete
# Working on: 20160408 | 1 matches found |  18.1% complete
# Working on: 20160409 | 6 matches found |  18.3% complete
# Working on: 20160410 | 3 matches found |  18.4% complete
# Working on: 20160413 | 2 matches found |  18.6% complete
# Working on: 20160415 | 1 matches found |  18.7% complete
# Working on: 20160416 | 7 matches found |  18.8% complete
# Working on: 20160417 | 2 matches found |  19.0% complete
# Working on: 20160423 | 7 matches found |  19.1% complete
# Working on: 20160424 | 2 matches found |  19.2% complete
# Working on: 20160427 | 1 matches found |  19.4% complete
# Working on: 20160429 | 1 matches found |  19.5% complete
# Working on: 20160430 | 7 matches found |  19.6% complete
# Working on: 20160501 | 2 matches found |  19.8% complete
# Working on: 20160506 | 1 matches found |  19.9% complete
# Working on: 20160507 | 6 matches found |  20.1% complete
# Working on: 20160508 | 2 matches found |  20.2% complete
# Working on: 20160511 | 5 matches found |  20.3% complete
# Working on: 20160513 | 1 matches found |  20.5% complete
# Working on: 20160514 | 5 matches found |  20.6% complete
# Working on: 20160515 | 3 matches found |  20.7% complete
# Working on: 20160518 | 1 matches found |  20.9% complete
# Working on: 20160520 | 1 matches found |  21.0% complete
# Working on: 20160521 | 7 matches found |  21.1% complete
# Working on: 20160522 | 2 matches found |  21.3% complete
# Working on: 20160525 | 1 matches found |  21.4% complete
# Working on: 20160527 | 1 matches found |  21.6% complete
# Working on: 20160528 | 1 matches found |  21.7% complete
# Working on: 20160529 | 1 matches found |  21.8% complete
# Working on: 20160601 | 1 matches found |  22.0% complete
# Working on: 20160602 | 3 matches found |  22.1% complete
# Working on: 20160618 | 1 matches found |  22.2% complete
# Working on: 20160619 | 2 matches found |  22.4% complete
# Working on: 20160622 | 2 matches found |  22.5% complete
# Working on: 20160625 | 3 matches found |  22.6% complete
# Working on: 20160626 | 3 matches found |  22.8% complete
# Working on: 20160701 | 1 matches found |  22.9% complete
# Working on: 20160702 | 1 matches found |  23.1% complete
# Working on: 20160703 | 1 matches found |  23.2% complete
# Working on: 20160704 | 3 matches found |  23.3% complete
# Working on: 20160706 | 1 matches found |  23.5% complete
# Working on: 20160708 | 2 matches found |  23.6% complete
# Working on: 20160709 | 6 matches found |  23.7% complete
# Working on: 20160710 | 1 matches found |  23.9% complete
# Working on: 20160713 | 7 matches found |  24.0% complete
# Working on: 20160715 | 1 matches found |  24.1% complete
# Working on: 20160716 | 6 matches found |  24.3% complete
# Working on: 20160717 | 3 matches found |  24.4% complete
# Working on: 20160722 | 1 matches found |  24.6% complete
# Working on: 20160723 | 7 matches found |  24.7% complete
# Working on: 20160724 | 2 matches found |  24.8% complete
# Working on: 20160730 | 1 matches found |  25.0% complete
# Working on: 20160731 | 9 matches found |  25.1% complete
# Working on: 20160803 | 10 matches found |  25.2% complete
# Working on: 20160805 | 1 matches found |  25.4% complete
# Working on: 20160806 | 5 matches found |  25.5% complete
# Working on: 20160807 | 2 matches found |  25.6% complete
# Working on: 20160812 | 1 matches found |  25.8% complete
# Working on: 20160813 | 4 matches found |  25.9% complete
# Working on: 20160814 | 3 matches found |  26.1% complete
# Working on: 20160819 | 1 matches found |  26.2% complete
# Working on: 20160820 | 1 matches found |  26.3% complete
# Working on: 20160821 | 2 matches found |  26.5% complete
# Working on: 20160824 | 5 matches found |  26.6% complete
# Working on: 20160826 | 1 matches found |  26.7% complete
# Working on: 20160827 | 6 matches found |  26.9% complete
# Working on: 20160828 | 3 matches found |  27.0% complete
# Working on: 20160901 | 3 matches found |  27.1% complete
# Working on: 20160903 | 5 matches found |  27.3% complete
# Working on: 20160907 | 2 matches found |  27.4% complete
# Working on: 20160909 | 1 matches found |  27.6% complete
# Working on: 20160910 | 7 matches found |  27.7% complete
# Working on: 20160911 | 2 matches found |  27.8% complete
# Working on: 20160916 | 1 matches found |  28.0% complete
# Working on: 20160917 | 7 matches found |  28.1% complete
# Working on: 20160918 | 2 matches found |  28.2% complete
# Working on: 20160923 | 1 matches found |  28.4% complete
# Working on: 20160924 | 7 matches found |  28.5% complete
# Working on: 20160925 | 2 matches found |  28.6% complete
# Working on: 20160928 | 2 matches found |  28.8% complete
# Working on: 20160930 | 1 matches found |  28.9% complete
# Working on: 20161001 | 7 matches found |  29.1% complete
# Working on: 20161002 | 2 matches found |  29.2% complete
# Working on: 20161008 | 1 matches found |  29.3% complete
# Working on: 20161012 | 1 matches found |  29.5% complete
# Working on: 20161013 | 2 matches found |  29.6% complete
# Working on: 20161016 | 10 matches found |  29.7% complete
# Working on: 20161023 | 10 matches found |  29.9% complete
# Working on: 20161026 | 2 matches found |  30.0% complete
# Working on: 20161027 | 2 matches found |  30.2% complete
# Working on: 20161030 | 4 matches found |  30.3% complete
# Working on: 20161106 | 4 matches found |  30.4% complete
# Working on: 20161122 | 2 matches found |  30.6% complete
# Working on: 20161127 | 1 matches found |  30.7% complete
# Working on: 20161130 | 1 matches found |  30.8% complete
# Working on: 20161210 | 1 matches found |  31.0% complete
# Working on: 20170303 | 1 matches found |  31.1% complete
# Working on: 20170304 | 7 matches found |  31.2% complete
# Working on: 20170305 | 3 matches found |  31.4% complete
# Working on: 20170311 | 7 matches found |  31.5% complete
# Working on: 20170312 | 3 matches found |  31.7% complete
# Working on: 20170318 | 10 matches found |  31.8% complete
# Working on: 20170319 | 1 matches found |  31.9% complete
# Working on: 20170325 | 3 matches found |  32.1% complete
# Working on: 20170331 | 2 matches found |  32.2% complete
# Working on: 20170401 | 7 matches found |  32.3% complete
# Working on: 20170402 | 1 matches found |  32.5% complete
# Working on: 20170407 | 1 matches found |  32.6% complete
# Working on: 20170408 | 8 matches found |  32.7% complete
# Working on: 20170409 | 2 matches found |  32.9% complete
# Working on: 20170414 | 3 matches found |  33.0% complete
# Working on: 20170415 | 8 matches found |  33.2% complete
# Working on: 20170419 | 2 matches found |  33.3% complete
# Working on: 20170421 | 1 matches found |  33.4% complete
# Working on: 20170422 | 7 matches found |  33.6% complete
# Working on: 20170423 | 3 matches found |  33.7% complete
# Working on: 20170428 | 1 matches found |  33.8% complete
# Working on: 20170429 | 9 matches found |  34.0% complete
# Working on: 20170430 | 1 matches found |  34.1% complete
# Working on: 20170503 | 1 matches found |  34.2% complete
# Working on: 20170505 | 1 matches found |  34.4% complete
# Working on: 20170506 | 8 matches found |  34.5% complete
# Working on: 20170507 | 2 matches found |  34.7% complete
# Working on: 20170510 | 1 matches found |  34.8% complete
# Working on: 20170512 | 1 matches found |  34.9% complete
# Working on: 20170513 | 7 matches found |  35.1% complete
# Working on: 20170514 | 3 matches found |  35.2% complete
# Working on: 20170517 | 5 matches found |  35.3% complete
# Working on: 20170519 | 1 matches found |  35.5% complete
# Working on: 20170520 | 7 matches found |  35.6% complete
# Working on: 20170521 | 3 matches found |  35.7% complete
# Working on: 20170525 | 1 matches found |  35.9% complete
# Working on: 20170526 | 1 matches found |  36.0% complete
# Working on: 20170527 | 7 matches found |  36.2% complete
# Working on: 20170528 | 2 matches found |  36.3% complete
# Working on: 20170531 | 4 matches found |  36.4% complete
# Working on: 20170602 | 1 matches found |  36.6% complete
# Working on: 20170603 | 1 matches found |  36.7% complete
# Working on: 20170604 | 2 matches found |  36.8% complete
# Working on: 20170610 | 1 matches found |  37.0% complete
# Working on: 20170617 | 10 matches found |  37.1% complete
# Working on: 20170618 | 1 matches found |  37.2% complete
# Working on: 20170621 | 4 matches found |  37.4% complete
# Working on: 20170623 | 2 matches found |  37.5% complete
# Working on: 20170624 | 8 matches found |  37.7% complete
# Working on: 20170625 | 1 matches found |  37.8% complete
# Working on: 20170629 | 50 matches found |  37.9% complete
# Working on: 20170630 | 1 matches found |  38.1% complete
# Working on: 20170701 | 7 matches found |  38.2% complete
# Working on: 20170702 | 1 matches found |  38.3% complete
# Working on: 20170704 | 5 matches found |  38.5% complete
# Working on: 20170705 | 5 matches found |  38.6% complete
# Working on: 20170706 | 48 matches found |  38.7% complete
# Working on: 20170719 | 10 matches found |  38.9% complete
# Working on: 20170721 | 1 matches found |  39.0% complete
# Working on: 20170722 | 8 matches found |  39.2% complete
# Working on: 20170723 | 2 matches found |  39.3% complete
# Working on: 20170726 | 9 matches found |  39.4% complete
# Working on: 20170729 | 10 matches found |  39.6% complete
# Working on: 20170730 | 1 matches found |  39.7% complete
# Working on: 20170805 | 8 matches found |  39.8% complete
# Working on: 20170806 | 3 matches found |  40.0% complete
# Working on: 20170812 | 10 matches found |  40.1% complete
# Working on: 20170813 | 1 matches found |  40.2% complete
# Working on: 20170816 | 5 matches found |  40.4% complete
# Working on: 20170818 | 1 matches found |  40.5% complete
# Working on: 20170819 | 7 matches found |  40.7% complete
# Working on: 20170820 | 2 matches found |  40.8% complete
# Working on: 20170823 | 5 matches found |  40.9% complete
# Working on: 20170825 | 1 matches found |  41.1% complete
# Working on: 20170826 | 6 matches found |  41.2% complete
# Working on: 20170827 | 3 matches found |  41.3% complete
# Working on: 20170902 | 1 matches found |  41.5% complete
# Working on: 20170906 | 1 matches found |  41.6% complete
# Working on: 20170909 | 8 matches found |  41.7% complete
# Working on: 20170910 | 3 matches found |  41.9% complete
# Working on: 20170913 | 2 matches found |  42.0% complete
# Working on: 20170916 | 10 matches found |  42.2% complete
# Working on: 20170917 | 1 matches found |  42.3% complete
# Working on: 20170920 | 2 matches found |  42.4% complete
# Working on: 20170923 | 8 matches found |  42.6% complete
# Working on: 20170924 | 3 matches found |  42.7% complete
# Working on: 20170927 | 2 matches found |  42.8% complete
# Working on: 20170930 | 10 matches found |  43.0% complete
# Working on: 20171001 | 1 matches found |  43.1% complete
# Working on: 20171003 | 1 matches found |  43.2% complete
# Working on: 20171007 | 2 matches found |  43.4% complete
# Working on: 20171011 | 1 matches found |  43.5% complete
# Working on: 20171015 | 11 matches found |  43.7% complete
# Working on: 20171022 | 11 matches found |  43.8% complete
# Working on: 20171025 | 2 matches found |  43.9% complete
# Working on: 20171026 | 2 matches found |  44.1% complete
# Working on: 20171029 | 1 matches found |  44.2% complete
# Working on: 20171030 | 2 matches found |  44.3% complete
# Working on: 20171031 | 2 matches found |  44.5% complete
# Working on: 20171102 | 2 matches found |  44.6% complete
# Working on: 20171105 | 3 matches found |  44.7% complete
# Working on: 20171121 | 2 matches found |  44.9% complete
# Working on: 20171129 | 1 matches found |  45.0% complete
# Working on: 20171130 | 1 matches found |  45.2% complete
# Working on: 20171209 | 1 matches found |  45.3% complete
# Working on: 20180303 | 6 matches found |  45.4% complete
# Working on: 20180304 | 4 matches found |  45.6% complete
# Working on: 20180310 | 7 matches found |  45.7% complete
# Working on: 20180311 | 2 matches found |  45.8% complete
# Working on: 20180317 | 8 matches found |  46.0% complete
# Working on: 20180318 | 1 matches found |  46.1% complete
# Working on: 20180324 | 6 matches found |  46.2% complete
# Working on: 20180330 | 1 matches found |  46.4% complete
# Working on: 20180331 | 10 matches found |  46.5% complete
# Working on: 20180406 | 1 matches found |  46.7% complete
# Working on: 20180407 | 5 matches found |  46.8% complete
# Working on: 20180408 | 2 matches found |  46.9% complete
# Working on: 20180411 | 2 matches found |  47.1% complete
# Working on: 20180413 | 2 matches found |  47.2% complete
# Working on: 20180414 | 7 matches found |  47.3% complete
# Working on: 20180415 | 2 matches found |  47.5% complete
# Working on: 20180420 | 1 matches found |  47.6% complete
# Working on: 20180421 | 8 matches found |  47.7% complete
# Working on: 20180422 | 2 matches found |  47.9% complete
# Working on: 20180427 | 1 matches found |  48.0% complete
# Working on: 20180428 | 7 matches found |  48.2% complete
# Working on: 20180429 | 3 matches found |  48.3% complete
# Working on: 20180504 | 1 matches found |  48.4% complete
# Working on: 20180505 | 9 matches found |  48.6% complete
# Working on: 20180506 | 1 matches found |  48.7% complete
# Working on: 20180509 | 5 matches found |  48.8% complete
# Working on: 20180511 | 1 matches found |  49.0% complete
# Working on: 20180512 | 7 matches found |  49.1% complete
# Working on: 20180513 | 3 matches found |  49.2% complete
# Working on: 20180516 | 1 matches found |  49.4% complete
# Working on: 20180518 | 1 matches found |  49.5% complete
# Working on: 20180519 | 6 matches found |  49.7% complete
# Working on: 20180520 | 3 matches found |  49.8% complete
# Working on: 20180521 | 1 matches found |  49.9% complete
# Working on: 20180525 | 3 matches found |  50.1% complete
# Working on: 20180526 | 1 matches found |  50.2% complete
# Working on: 20180527 | 1 matches found |  50.3% complete
# Working on: 20180530 | 4 matches found |  50.5% complete
# Working on: 20180601 | 1 matches found |  50.6% complete
# Working on: 20180602 | 9 matches found |  50.8% complete
# Working on: 20180603 | 1 matches found |  50.9% complete
# Working on: 20180608 | 1 matches found |  51.0% complete
# Working on: 20180609 | 10 matches found |  51.2% complete
# Working on: 20180613 | 6 matches found |  51.3% complete
# Working on: 20180623 | 2 matches found |  51.4% complete
# Working on: 20180624 | 1 matches found |  51.6% complete
# Working on: 20180629 | 1 matches found |  51.7% complete
# Working on: 20180630 | 2 matches found |  51.8% complete
# Working on: 20180701 | 2 matches found |  52.0% complete
# Working on: 20180703 | 2 matches found |  52.1% complete
# Working on: 20180704 | 5 matches found |  52.3% complete
# Working on: 20180707 | 2 matches found |  52.4% complete
# Working on: 20180708 | 1 matches found |  52.5% complete
# Working on: 20180711 | 1 matches found |  52.7% complete
# Working on: 20180714 | 1 matches found |  52.8% complete
# Working on: 20180715 | 1 matches found |  52.9% complete
# Working on: 20180718 | 6 matches found |  53.1% complete
# Working on: 20180721 | 9 matches found |  53.2% complete
# Working on: 20180722 | 1 matches found |  53.3% complete
# Working on: 20180725 | 5 matches found |  53.5% complete
# Working on: 20180726 | 46 matches found |  53.6% complete
# Working on: 20180728 | 8 matches found |  53.8% complete
# Working on: 20180729 | 2 matches found |  53.9% complete
# Working on: 20180804 | 10 matches found |  54.0% complete
# Working on: 20180805 | 1 matches found |  54.2% complete
# Working on: 20180811 | 8 matches found |  54.3% complete
# Working on: 20180812 | 3 matches found |  54.4% complete
# Working on: 20180814 | 10 matches found |  54.6% complete
# Working on: 20180815 | 1 matches found |  54.7% complete
# Working on: 20180818 | 8 matches found |  54.8% complete
# Working on: 20180819 | 3 matches found |  55.0% complete
# Working on: 20180822 | 3 matches found |  55.1% complete
# Working on: 20180823 | 21 matches found |  55.3% complete
# Working on: 20180824 | 2 matches found |  55.4% complete
# Working on: 20180825 | 5 matches found |  55.5% complete
# Working on: 20180826 | 2 matches found |  55.7% complete
# Working on: 20180829 | 3 matches found |  55.8% complete
# Working on: 20180901 | 9 matches found |  55.9% complete
# Working on: 20180902 | 1 matches found |  56.1% complete
# Working on: 20180905 | 1 matches found |  56.2% complete
# Working on: 20180908 | 1 matches found |  56.3% complete
# Working on: 20180912 | 1 matches found |  56.5% complete
# Working on: 20180915 | 9 matches found |  56.6% complete
# Working on: 20180916 | 2 matches found |  56.8% complete
# Working on: 20180919 | 2 matches found |  56.9% complete
# Working on: 20180922 | 8 matches found |  57.0% complete
# Working on: 20180923 | 3 matches found |  57.2% complete
# Working on: 20180926 | 1 matches found |  57.3% complete
# Working on: 20180929 | 9 matches found |  57.4% complete
# Working on: 20180930 | 2 matches found |  57.6% complete
# Working on: 20181006 | 9 matches found |  57.7% complete
# Working on: 20181007 | 1 matches found |  57.8% complete
# Working on: 20181008 | 1 matches found |  58.0% complete
# Working on: 20181012 | 1 matches found |  58.1% complete
# Working on: 20181013 | 1 matches found |  58.3% complete
# Working on: 20181017 | 3 matches found |  58.4% complete
# Working on: 20181018 | 1 matches found |  58.5% complete
# Working on: 20181021 | 11 matches found |  58.7% complete
# Working on: 20181028 | 11 matches found |  58.8% complete
# Working on: 20181031 | 2 matches found |  58.9% complete
# Working on: 20181101 | 2 matches found |  59.1% complete
# Working on: 20181104 | 4 matches found |  59.2% complete
# Working on: 20181108 | 2 matches found |  59.3% complete
# Working on: 20181111 | 3 matches found |  59.5% complete
# Working on: 20181125 | 2 matches found |  59.6% complete
# Working on: 20181129 | 2 matches found |  59.8% complete
# Working on: 20181208 | 1 matches found |  59.9% complete
# Working on: 20190302 | 10 matches found |  60.0% complete
# Working on: 20190303 | 2 matches found |  60.2% complete
# Working on: 20190309 | 7 matches found |  60.3% complete
# Working on: 20190310 | 4 matches found |  60.4% complete
# Working on: 20190316 | 7 matches found |  60.6% complete
# Working on: 20190317 | 5 matches found |  60.7% complete
# Working on: 20190323 | 2 matches found |  60.8% complete
# Working on: 20190324 | 2 matches found |  61.0% complete
# Working on: 20190329 | 1 matches found |  61.1% complete
# Working on: 20190330 | 9 matches found |  61.3% complete
# Working on: 20190331 | 2 matches found |  61.4% complete
# Working on: 20190405 | 1 matches found |  61.5% complete
# Working on: 20190406 | 9 matches found |  61.7% complete
# Working on: 20190407 | 1 matches found |  61.8% complete
# Working on: 20190409 | 2 matches found |  61.9% complete
# Working on: 20190412 | 1 matches found |  62.1% complete
# Working on: 20190413 | 10 matches found |  62.2% complete
# Working on: 20190414 | 1 matches found |  62.3% complete
# Working on: 20190417 | 2 matches found |  62.5% complete
# Working on: 20190419 | 3 matches found |  62.6% complete
# Working on: 20190420 | 7 matches found |  62.8% complete
# Working on: 20190421 | 2 matches found |  62.9% complete
# Working on: 20190424 | 5 matches found |  63.0% complete
# Working on: 20190427 | 8 matches found |  63.2% complete
# Working on: 20190428 | 4 matches found |  63.3% complete
# Working on: 20190501 | 1 matches found |  63.4% complete
# Working on: 20190503 | 1 matches found |  63.6% complete
# Working on: 20190504 | 10 matches found |  63.7% complete
# Working on: 20190505 | 1 matches found |  63.8% complete
# Working on: 20190508 | 1 matches found |  64.0% complete
# Working on: 20190510 | 1 matches found |  64.1% complete
# Working on: 20190511 | 9 matches found |  64.3% complete
# Working on: 20190512 | 2 matches found |  64.4% complete
# Working on: 20190515 | 4 matches found |  64.5% complete
# Working on: 20190516 | 1 matches found |  64.7% complete
# Working on: 20190518 | 7 matches found |  64.8% complete
# Working on: 20190519 | 4 matches found |  64.9% complete
# Working on: 20190522 | 1 matches found |  65.1% complete
# Working on: 20190524 | 3 matches found |  65.2% complete
# Working on: 20190525 | 7 matches found |  65.3% complete
# Working on: 20190526 | 2 matches found |  65.5% complete
# Working on: 20190529 | 1 matches found |  65.6% complete
# Working on: 20190531 | 1 matches found |  65.8% complete
# Working on: 20190601 | 1 matches found |  65.9% complete
# Working on: 20190602 | 2 matches found |  66.0% complete
# Working on: 20190605 | 1 matches found |  66.2% complete
# Working on: 20190606 | 5 matches found |  66.3% complete
# Working on: 20190607 | 2 matches found |  66.4% complete
# Working on: 20190608 | 2 matches found |  66.6% complete
# Working on: 20190622 | 2 matches found |  66.7% complete
# Working on: 20190623 | 2 matches found |  66.8% complete
# Working on: 20190626 | 6 matches found |  67.0% complete
# Working on: 20190628 | 1 matches found |  67.1% complete
# Working on: 20190629 | 1 matches found |  67.3% complete
# Working on: 20190630 | 1 matches found |  67.4% complete
# Working on: 20190703 | 1 matches found |  67.5% complete
# Working on: 20190704 | 6 matches found |  67.7% complete
# Working on: 20190706 | 1 matches found |  67.8% complete
# Working on: 20190707 | 1 matches found |  67.9% complete
# Working on: 20190712 | 3 matches found |  68.1% complete
# Working on: 20190713 | 7 matches found |  68.2% complete
# Working on: 20190714 | 2 matches found |  68.3% complete
# Working on: 20190717 | 10 matches found |  68.5% complete
# Working on: 20190718 | 43 matches found |  68.6% complete
# Working on: 20190719 | 1 matches found |  68.8% complete
# Working on: 20190720 | 7 matches found |  68.9% complete
# Working on: 20190721 | 4 matches found |  69.0% complete
# Working on: 20190726 | 2 matches found |  69.2% complete
# Working on: 20190727 | 10 matches found |  69.3% complete
# Working on: 20190803 | 9 matches found |  69.4% complete
# Working on: 20190804 | 3 matches found |  69.6% complete
# Working on: 20190808 | 32 matches found |  69.7% complete
# Working on: 20190810 | 8 matches found |  69.8% complete
# Working on: 20190811 | 4 matches found |  70.0% complete
# Working on: 20190814 | 3 matches found |  70.1% complete
# Working on: 20190817 | 11 matches found |  70.3% complete
# Working on: 20190818 | 1 matches found |  70.4% complete
# Working on: 20190821 | 3 matches found |  70.5% complete
# Working on: 20190822 | 21 matches found |  70.7% complete
# Working on: 20190823 | 2 matches found |  70.8% complete
# Working on: 20190824 | 6 matches found |  70.9% complete
# Working on: 20190825 | 3 matches found |  71.1% complete
# Working on: 20190828 | 3 matches found |  71.2% complete
# Working on: 20190831 | 10 matches found |  71.4% complete
# Working on: 20190901 | 2 matches found |  71.5% complete
# Working on: 20190907 | 2 matches found |  71.6% complete
# Working on: 20190911 | 4 matches found |  71.8% complete
# Working on: 20190914 | 7 matches found |  71.9% complete
# Working on: 20190915 | 5 matches found |  72.0% complete
# Working on: 20190918 | 2 matches found |  72.2% complete
# Working on: 20190921 | 8 matches found |  72.3% complete
# Working on: 20190922 | 4 matches found |  72.4% complete
# Working on: 20190925 | 6 matches found |  72.6% complete
# Working on: 20190929 | 12 matches found |  72.7% complete
# Working on: 20191006 | 12 matches found |  72.9% complete
# Working on: 20191019 | 4 matches found |  73.0% complete
# Working on: 20191020 | 2 matches found |  73.1% complete
# Working on: 20191023 | 2 matches found |  73.3% complete
# Working on: 20191024 | 2 matches found |  73.4% complete
# Working on: 20191029 | 1 matches found |  73.5% complete
# Working on: 20191030 | 1 matches found |  73.7% complete
# Working on: 20191110 | 1 matches found |  73.8% complete
# Working on: 20200229 | 8 matches found |  73.9% complete
# Working on: 20200301 | 5 matches found |  74.1% complete
# Working on: 20200307 | 11 matches found |  74.2% complete
# Working on: 20200308 | 2 matches found |  74.4% complete
# Working on: 20200708 | 4 matches found |  74.5% complete
# Working on: 20200709 | 1 matches found |  74.6% complete
# Working on: 20200710 | 1 matches found |  74.8% complete
# Working on: 20200711 | 10 matches found |  74.9% complete
# Working on: 20200712 | 2 matches found |  75.0% complete
# Working on: 20200713 | 1 matches found |  75.2% complete
# Working on: 20200714 | 2 matches found |  75.3% complete
# Working on: 20200715 | 1 matches found |  75.4% complete
# Working on: 20200716 | 1 matches found |  75.6% complete
# Working on: 20200717 | 1 matches found |  75.7% complete
# Working on: 20200718 | 11 matches found |  75.9% complete
# Working on: 20200719 | 2 matches found |  76.0% complete
# Working on: 20200720 | 2 matches found |  76.1% complete
# Working on: 20200721 | 2 matches found |  76.3% complete
# Working on: 20200722 | 2 matches found |  76.4% complete
# Working on: 20200723 | 1 matches found |  76.5% complete
# Working on: 20200725 | 12 matches found |  76.7% complete
# Working on: 20200726 | 2 matches found |  76.8% complete
# Working on: 20200727 | 2 matches found |  76.9% complete
# Working on: 20200728 | 2 matches found |  77.1% complete
# Working on: 20200730 | 1 matches found |  77.2% complete
# Working on: 20200731 | 1 matches found |  77.4% complete
# Working on: 20200801 | 11 matches found |  77.5% complete
# Working on: 20200805 | 4 matches found |  77.6% complete
# Working on: 20200806 | 4 matches found |  77.8% complete
# Working on: 20200811 | 1 matches found |  77.9% complete
# Working on: 20200812 | 1 matches found |  78.0% complete
# Working on: 20200816 | 1 matches found |  78.2% complete
# Working on: 20200818 | 1 matches found |  78.3% complete
# Working on: 20200820 | 5 matches found |  78.4% complete
# Working on: 20200821 | 1 matches found |  78.6% complete
# Working on: 20200822 | 1 matches found |  78.7% complete
# Working on: 20200823 | 1 matches found |  78.9% complete
# Working on: 20200824 | 1 matches found |  79.0% complete
# Working on: 20200825 | 2 matches found |  79.1% complete
# Working on: 20200826 | 11 matches found |  79.3% complete
# Working on: 20200828 | 2 matches found |  79.4% complete
# Working on: 20200829 | 17 matches found |  79.5% complete
# Working on: 20200830 | 5 matches found |  79.7% complete
# Working on: 20200901 | 1 matches found |  79.8% complete
# Working on: 20200902 | 11 matches found |  79.9% complete
# Working on: 20200905 | 2 matches found |  80.1% complete
# Working on: 20200906 | 2 matches found |  80.2% complete
# Working on: 20200909 | 1 matches found |  80.4% complete
# Working on: 20200910 | 1 matches found |  80.5% complete
# Working on: 20200912 | 12 matches found |  80.6% complete
# Working on: 20200913 | 8 matches found |  80.8% complete
# Working on: 20200916 | 5 matches found |  80.9% complete
# Working on: 20200918 | 1 matches found |  81.0% complete
# Working on: 20200919 | 20 matches found |  81.2% complete
# Working on: 20200920 | 1 matches found |  81.3% complete
# Working on: 20200923 | 3 matches found |  81.4% complete
# Working on: 20200926 | 2 matches found |  81.6% complete
# Working on: 20200927 | 11 matches found |  81.7% complete
# Working on: 20201003 | 11 matches found |  81.9% complete
# Working on: 20201004 | 1 matches found |  82.0% complete
# Working on: 20201006 | 1 matches found |  82.1% complete
# Working on: 20201007 | 12 matches found |  82.3% complete
# Working on: 20201010 | 2 matches found |  82.4% complete
# Working on: 20201011 | 2 matches found |  82.5% complete
# Working on: 20201014 | 2 matches found |  82.7% complete
# Working on: 20201017 | 2 matches found |  82.8% complete
# Working on: 20201018 | 9 matches found |  82.9% complete
# Working on: 20201019 | 1 matches found |  83.1% complete
# Working on: 20201020 | 2 matches found |  83.2% complete
# Working on: 20201022 | 2 matches found |  83.4% complete
# Working on: 20201023 | 1 matches found |  83.5% complete
# Working on: 20201024 | 10 matches found |  83.6% complete
# Working on: 20201025 | 1 matches found |  83.8% complete
# Working on: 20201027 | 2 matches found |  83.9% complete
# Working on: 20201028 | 2 matches found |  84.0% complete
# Working on: 20201031 | 2 matches found |  84.2% complete
# Working on: 20201101 | 9 matches found |  84.3% complete
# Working on: 20201104 | 2 matches found |  84.4% complete
# Working on: 20201108 | 13 matches found |  84.6% complete
# Working on: 20201120 | 2 matches found |  84.7% complete
# Working on: 20201121 | 2 matches found |  84.9% complete
# Working on: 20201122 | 3 matches found |  85.0% complete
# Working on: 20201124 | 2 matches found |  85.1% complete
# Working on: 20201129 | 2 matches found |  85.3% complete
# Working on: 20201201 | 2 matches found |  85.4% complete
# Working on: 20201203 | 2 matches found |  85.5% complete
# Working on: 20201206 | 1 matches found |  85.7% complete
# Working on: 20201207 | 1 matches found |  85.8% complete
# Working on: 20201212 | 1 matches found |  85.9% complete
# Working on: 20210416 | 2 matches found |  86.1% complete
# Working on: 20210417 | 8 matches found |  86.2% complete
# Working on: 20210418 | 3 matches found |  86.4% complete
# Working on: 20210423 | 1 matches found |  86.5% complete
# Working on: 20210424 | 11 matches found |  86.6% complete
# Working on: 20210425 | 1 matches found |  86.8% complete
# Working on: 20210501 | 10 matches found |  86.9% complete
# Working on: 20210502 | 3 matches found |  87.0% complete
# Working on: 20210507 | 1 matches found |  87.2% complete
# Working on: 20210508 | 9 matches found |  87.3% complete
# Working on: 20210509 | 3 matches found |  87.4% complete
# Working on: 20210512 | 6 matches found |  87.6% complete
# Working on: 20210513 | 1 matches found |  87.7% complete
# Working on: 20210515 | 8 matches found |  87.9% complete
# Working on: 20210516 | 5 matches found |  88.0% complete
# Working on: 20210522 | 10 matches found |  88.1% complete
# Working on: 20210523 | 3 matches found |  88.3% complete
# Working on: 20210529 | 1 matches found |  88.4% complete
# Working on: 20210530 | 1 matches found |  88.5% complete
# Working on: 20210612 | 1 matches found |  88.7% complete
# Working on: 20210618 | 2 matches found |  88.8% complete
# Working on: 20210619 | 1 matches found |  88.9% complete
# Working on: 20210620 | 2 matches found |  89.1% complete
# Working on: 20210622 | 2 matches found |  89.2% complete
# Working on: 20210623 | 2 matches found |  89.4% complete
# Working on: 20210625 | 1 matches found |  89.5% complete
# Working on: 20210626 | 2 matches found |  89.6% complete
# Working on: 20210627 | 2 matches found |  89.8% complete
# Working on: 20210701 | 1 matches found |  89.9% complete
# Working on: 20210703 | 2 matches found |  90.0% complete
# Working on: 20210704 | 3 matches found |  90.2% complete
# Working on: 20210707 | 1 matches found |  90.3% complete
# Working on: 20210708 | 30 matches found |  90.5% complete
# Working on: 20210709 | 1 matches found |  90.6% complete
# Working on: 20210717 | 11 matches found |  90.7% complete
# Working on: 20210718 | 1 matches found |  90.9% complete
# Working on: 20210720 | 6 matches found |  91.0% complete
# Working on: 20210721 | 7 matches found |  91.1% complete
# Working on: 20210722 | 2 matches found |  91.3% complete
# Working on: 20210724 | 8 matches found |  91.4% complete
# Working on: 20210725 | 2 matches found |  91.5% complete
# Working on: 20210728 | 9 matches found |  91.7% complete
# Working on: 20210730 | 3 matches found |  91.8% complete
# Working on: 20210731 | 4 matches found |  92.0% complete
# Working on: 20210801 | 2 matches found |  92.1% complete
# Working on: 20210804 | 3 matches found |  92.2% complete
# Working on: 20210807 | 1 matches found |  92.4% complete
# Working on: 20210808 | 6 matches found |  92.5% complete
# Working on: 20210813 | 1 matches found |  92.6% complete
# Working on: 20210814 | 7 matches found |  92.8% complete
# Working on: 20210815 | 4 matches found |  92.9% complete
# Working on: 20210817 | 3 matches found |  93.0% complete
# Working on: 20210818 | 3 matches found |  93.2% complete
# Working on: 20210820 | 1 matches found |  93.3% complete
# Working on: 20210821 | 12 matches found |  93.5% complete
# Working on: 20210827 | 3 matches found |  93.6% complete
# Working on: 20210828 | 7 matches found |  93.7% complete
# Working on: 20210829 | 3 matches found |  93.9% complete
# Working on: 20210903 | 2 matches found |  94.0% complete
# Working on: 20210904 | 2 matches found |  94.1% complete
# Working on: 20210910 | 2 matches found |  94.3% complete
# Working on: 20210911 | 10 matches found |  94.4% complete
# Working on: 20210912 | 1 matches found |  94.5% complete
# Working on: 20210914 | 2 matches found |  94.7% complete
# Working on: 20210915 | 2 matches found |  94.8% complete
# Working on: 20210917 | 1 matches found |  95.0% complete
# Working on: 20210918 | 8 matches found |  95.1% complete
# Working on: 20210919 | 4 matches found |  95.2% complete
# Working on: 20210922 | 3 matches found |  95.4% complete
# Working on: 20210925 | 10 matches found |  95.5% complete
# Working on: 20210926 | 3 matches found |  95.6% complete
# Working on: 20210929 | 2 matches found |  95.8% complete
# Working on: 20211002 | 6 matches found |  95.9% complete
# Working on: 20211003 | 7 matches found |  96.0% complete
# Working on: 20211009 | 2 matches found |  96.2% complete
# Working on: 20211010 | 2 matches found |  96.3% complete
# Working on: 20211016 | 11 matches found |  96.5% complete
# Working on: 20211017 | 2 matches found |  96.6% complete
# Working on: 20211020 | 2 matches found |  96.7% complete
# Working on: 20211023 | 11 matches found |  96.9% complete
# Working on: 20211024 | 2 matches found |  97.0% complete
# Working on: 20211026 | 1 matches found |  97.1% complete
# Working on: 20211027 | 11 matches found |  97.3% complete
# Working on: 20211030 | 6 matches found |  97.4% complete
# Working on: 20211031 | 4 matches found |  97.5% complete
# Working on: 20211101 | 1 matches found |  97.7% complete
# Working on: 20211102 | 2 matches found |  97.8% complete
# Working on: 20211103 | 2 matches found |  98.0% complete
# Working on: 20211107 | 13 matches found |  98.1% complete
# Working on: 20211120 | 2 matches found |  98.2% complete
# Working on: 20211121 | 2 matches found |  98.4% complete
# Working on: 20211123 | 2 matches found |  98.5% complete
# Working on: 20211125 | 2 matches found |  98.6% complete
# Working on: 20211128 | 2 matches found |  98.8% complete
# Working on: 20211130 | 1 matches found |  98.9% complete
# Working on: 20211204 | 1 matches found |  99.0% complete
# Working on: 20211205 | 1 matches found |  99.2% complete
# Working on: 20211211 | 1 matches found |  99.3% complete
# Working on: 20220226 | 9 matches found |  99.5% complete
# Working on: 20220227 | 5 matches found |  99.6% complete
# Working on: 20220305 | 12 matches found |  99.7% complete
# Working on: 20220306 | 2 matches found |  99.9% complete
# Working on: 20220312 | 12 matches found |  100.0% complete
# Total Matches: 2880

# %%
# save locally
fotmob_matches.to_csv('fotmob_matches.csv',header=True)
fotmob_matches.head()
# Out:
#         id  leagueId              time  statusId tournamentStage  \
# 0  1883624    838440  07.03.2015 04:20         6               1
# 0  1883625    838440  07.03.2015 21:10         6               1
# 1  1883631    838440  07.03.2015 22:05         6               1
# 2  1883626    838440  08.03.2015 00:05         6               1
# 3  1883633    838440  08.03.2015 02:40         6               1
#
#           timeTS    tv  home.id  home.score     home.name  \
# 0  1425669600000  None     6637           2     LA Galaxy
# 0  1425730200000  None     6602           1     DC United
# 1  1425733500000  None   191716           0  Philadelphia
# 2  1425740700000  None   307691           1     Vancouver
# 3  1425750000000  None     7949           1     FC Dallas
#
#          home.longName  away.id  away.score        away.name  \
# 0            LA Galaxy     6397           0          Chicago
# 0            DC United   307692           0  Montreal Impact
# 1   Philadelphia Union     8314           0         Colorado
# 2  Vancouver Whitecaps    56453           3          Toronto
# 3            FC Dallas     6603           0         San Jose
#
#           away.longName  status.finished  status.started  status.cancelled  \
# 0          Chicago Fire             True            True             False
# 0       Montreal Impact             True            True             False
# 1       Colorado Rapids             True            True             False
# 2            Toronto FC             True            True             False
# 3  San Jose Earthquakes             True            True             False
#
#   status.scoreStr status.startDateStr status.startDateStrShort  \
# 0           2 - 0         Mar 6, 2015                  6. Mar.
# 0           1 - 0         Mar 7, 2015                  7. Mar.
# 1           0 - 0         Mar 7, 2015                  7. Mar.
# 2           1 - 3         Mar 7, 2015                  7. Mar.
# 3           1 - 0         Mar 7, 2015                  7. Mar.
#
#   status.reason.short status.reason.long status.whoLostOnAggregated  \
# 0                  FT          Full-Time
# 0                  FT          Full-Time
# 1                  FT          Full-Time
# 2                  FT          Full-Time
# 3                  FT          Full-Time
#
#   status.aggregatedStr status.startTimeStr
# 0                  NaN                 NaN
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN

# %%
print(len(fotmob_matches),"matches")
# Out:
# 2880 matches

# %%
fotmob_matches['home.name'].value_counts()
# Out:
# Toronto             102
# Philadelphia        101
# Portland             97
# Seattle Sounders     97
# Houston              96
#                    ...
# CS Fola Esch          1
# Trepca 89             1
# Cracovia              1
# FK Spartaks           1
# Rostov                1
# Name: home.name, Length: 392, dtype: int64

# %%
# looks like we have a lot of non MLS teams... may be the 130 code is used in other competitions? 
# limit to just the games where an MLS team is hosting
mls_team_names = ['Toronto', 'Philadelphia', 'Seattle Sounders', 'Houston', 'Portland', 'Orlando', 'Columbus', 'LA Galaxy'
 ,'Vancouver', 'DC United', 'San Jose', 'New England', 'Salt Lake', 'Colorado', 'Sporting KC', 'NYCFC'
 , 'Chicago', 'NY Red Bulls', 'Atlanta United', 'Dallas', 'Minnesota', 'Montreal', 'LAFC', 'FC Dallas'
 , 'Montreal Impact', 'Cincinnati', 'Nashville SC', 'Inter Miami CF', 'Austin FC']

mls_fotmob_matches = fotmob_matches.loc[fotmob_matches['home.name'].isin(mls_team_names)]
print(len(mls_fotmob_matches),"mls matches")
# Out:
# 2115 mls matches

# %%
# Need a unique list of match IDs, luckily 100% of dupes are cancelled matches
# We'll also exclude the cancelled and never rescheduled matches at the same time
match_ids = mls_fotmob_matches['id'].loc[mls_fotmob_matches['status.cancelled']==False].unique()
print(len(match_ids),"unique matches")
# Out:
# 2022 unique matches

# %%
def extract_events(r):
    '''r = API response object'''
    events_df = pd.json_normalize(r.json()['content']['matchFacts']['events']['events'])
    # append match_ID and team_id for future joins, don't care about swaps so leaving in list form
    events_df['match_id'] = r.json()['general']['matchId']
    events_df.loc[(events_df['isHome'] == True ),'teamid'] = r.json()['general']['homeTeam']['id']
    events_df.loc[(events_df['isHome'] == False),'teamid'] = r.json()['general']['awayTeam']['id']
    return events_df

# %%
def extract_starting_players(r):
    '''r = API response object'''
    starting_players_df = pd.DataFrame()
    # loop through each team (0=home, 1=away)
    i=0
    for i in range(2):
        j=0
        # loop through each rank of players
        for j in range(len(r.json()['content']['lineup']['lineup'][i]['players'])):
            df = pd.json_normalize(r.json()['content']['lineup']['lineup'][i]['players'][j])
            starting_players_df = starting_players_df.append(df)
    # append match_id and team_id for future joining
    starting_players_df['match_id'] = r.json()['general']['matchId']
    starting_players_df.loc[(starting_players_df['isHomeTeam'] == True ),'teamid'] = r.json()['general']['homeTeam']['id']
    starting_players_df.loc[(starting_players_df['isHomeTeam'] == False),'teamid'] = r.json()['general']['awayTeam']['id']
    return starting_players_df

# %%
def extract_stats(r):
    '''r = API response object'''
    stats_df = pd.DataFrame()
    # check if stat data exists
    if r.json()['content']['stats'] == None:
        return stats_df
    i=0
    for i in range(len(r.json()['content']['stats']['stats'])):
        df = pd.json_normalize(r.json()['content']['stats']['stats'][i]['stats'])
        # split stats into home and away
        df[['home','away']] = pd.DataFrame(df.stats.tolist(), index= df.index)
        stats_df = stats_df.append(df)
    # append match_id for future joining
    stats_df['match_id'] = r.json()['general']['matchId']
    return stats_df

# %%
# %%time
Fotmob_matches_details_url = fotmob_url + '/matchDetails?matchId='
#all_events = pd.DataFrame()
#all_stats = pd.DataFrame()
#all_players = pd.DataFrame()
current_match = 386
total_matches = len(match_ids)
for match_id in match_ids[387:]:
    url = Fotmob_matches_details_url + str(match_id)
    r = requests.get(url)
    # check for a good response, if not try 1 more time after waiting a second
    if not r.ok:
        sleep(1)
        r = requests.get(url)
        # if still no luck, write the ID to an error file and move on
        if not r.ok:
            with open('match_errors', 'a') as errfile:
                errfile.write(str(match_id))
            continue
    all_events  = all_events.append(extract_events(r))
    all_players = all_players.append(extract_starting_players(r)) 
    all_stats   = all_stats.append(extract_stats(r))
    current_match +=1
    print(current_match," / ",total_matches, "completed - ","{:.1%}".format(current_match / total_matches),end ='\r')
    sleep(0.1) # just in case there are rate limits
print('\n')
print('Completed!')
# Out:
# 1533  /  2022 completed -  75.8%

# %%
match_ids[387]
# Out:
# 2162026

# %%
url = fotmob_url + '/matchDetails?matchId=' + str(match_ids[387])
r = requests.get(url)

# %%
all_events.to_csv('all_events.csv',header=True)
all_players.to_csv('all_players.csv',header=True)
all_stats.to_csv('all_stats.csv',header=True)

# %%
pd.json_normalize(r.json()['content']['matchFacts']['events']['events'])
# Out:
#                        reactKey  timeStr          type  time overloadTime  \
# 0   46SubstitutionNaN114339true       46  Substitution    46         None
# 1  55SubstitutionNaN431655false       55  Substitution    55         None
# 2         68Card0undefinedfalse       68          Card    68         None
# 3  74SubstitutionNaN342533false       74  Substitution    74         None
# 4   85SubstitutionNaN254852true       85  Substitution    85         None
# 5    85SubstitutionNaN30383true       85  Substitution    85         None
# 6  88SubstitutionNaN431650false       88  Substitution    88         None
#
#                  profileUrl  overloadTimeStr  isHome injuredPlayerOut  \
# 0             /players/NaN/            False    True            False
# 1             /players/NaN/            False   False            False
# 2  /players/0/bobby-burling            False   False              NaN
# 3             /players/NaN/            False   False            False
# 4             /players/NaN/            False    True            False
# 5             /players/NaN/            False    True            False
# 6             /players/NaN/            False   False            False
#
#                                                 swap  player.id  \
# 0  [{'name': 'Cristian Maidana', 'id': '114339', ...        NaN
# 1  [{'name': 'Dillon Powers', 'id': '431655', 'pr...        NaN
# 2                                                NaN        0.0
# 3  [{'name': 'Shane O'Neill', 'id': '342533', 'pr...        NaN
# 4  [{'name': 'Zach Pfeffer', 'id': '254852', 'pro...        NaN
# 5  [{'name': 'Conor Casey', 'id': '30383', 'profi...        NaN
# 6  [{'name': 'Deshorn Brown', 'id': '431650', 'pr...        NaN
#
#           player.profileUrl        nameStr       card    player.name
# 0       /players/undefined/            NaN        NaN            NaN
# 1       /players/undefined/            NaN        NaN            NaN
# 2  /players/0/bobby-burling  Bobby Burling  YellowRed  Bobby Burling
# 3       /players/undefined/            NaN        NaN            NaN
# 4       /players/undefined/            NaN        NaN            NaN
# 5       /players/undefined/            NaN        NaN            NaN
# 6       /players/undefined/            NaN        NaN            NaN

# %%
#url = fotmob_url + '/matchDetails?matchId=3787294'
url = fotmob_url + '/matchDetails?matchId=1883624'
r = requests.get(url)

# %%
if "stats" in r.json()['content']:
    print("true")
else:
    print("false")
# Out:
# true

# %%
if r.json()['content']['stats'] == None:
    print("True")
else:
    print("False")
# Out:
# True

# %%
r.json()['general']['homeTeam']
# Out:
# {'matchId': '3787294',
#  'matchName': 'Los Angeles FC-vs-Portland Timbers_Mon, Mar 7, 2022, 03:00 UTC',
#  'matchRound': None,
#  'teamColors': {'home': '#000000', 'away': '#004010'},
#  'leagueId': 10000002,
#  'leagueName': 'Major League Soccer',
#  'leagueRoundName': 'Major League Soccer null',
#  'parentLeagueId': 130,
#  'parentLeagueName': 'MLS',
#  'parentLeagueSeason': '2022',
#  'homeTeam': {'name': 'Los Angeles FC', 'id': 867280},
#  'awayTeam': {'name': 'Portland Timbers', 'id': 307690},
#  'matchTimeUTC': 'Mon, Mar 7, 2022, 03:00 UTC',
#  'started': True,
#  'finished': True}

# %%
r.json()['header']
# Out:
# {'teams': [{'name': 'Los Angeles FC',
#    'id': 867280,
#    'score': 1,
#    'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/867280_small.png',
#    'pageUrl': '/teams/867280/overview/los-angeles-fc',
#    'fifaRank': None},
#   {'name': 'Portland Timbers',
#    'id': 307690,
#    'score': 1,
#    'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/307690_small.png',
#    'pageUrl': '/teams/307690/overview/portland-timbers',
#    'fifaRank': None}],
#  'status': {'finished': True,
#   'started': True,
#   'cancelled': False,
#   'scoreStr': '1 - 1',
#   'startDateStr': 'Mar 6, 2022',
#   'startDateStrShort': '6. Mar.',
#   'reason': {'short': 'FT', 'long': 'Full-Time'},
#   'whoLostOnPenalties': None,
#   'whoLostOnAggregated': ''},
#  'events': {'homeTeamGoals': {'Fall': [{'reactKey': '90Goal1263370undefinedtrue',
#      'timeStr': '90 + 3',
#      'type': 'Goal',
#      'time': 90,
#      'overloadTime': 3,
#      'eventId': 8825684,
#      'player': {'id': 1263370,
#       'name': 'Mamadou Fall',
#       'profileUrl': '/players/1263370/mamadou-fall'},
#      'profileUrl': '/players/1263370/mamadou-fall',
#      'overloadTimeStr': '+3',
#      'isHome': True,
#      'ownGoal': None,
#      'suffix': None,
#      'isPenaltyShootoutEvent': False,
#      'nameStr': 'Mamadou Fall',
#      'firstName': 'Mamadou',
#      'lastName': 'Fall',
#      'playerId': 1263370,
#      'newScore': [1, 1],
#      'penShootoutScore': None,
#      'assistStr': 'assist by Brian Rodriguez',
#      'assistProfileUrl': '/players/941660/brian-rodriguez',
#      'assistPlayerId': 941660}]},
#   'awayTeamGoals': {'Chara': [{'reactKey': '18Goal244298undefinedfalse',
#      'timeStr': 18,
#      'type': 'Goal',
#      'time': 18,
#      'overloadTime': None,
#      'eventId': 8825659,
#      'player': {'id': 244298,
#       'name': 'Yimmi Chara',
#       'profileUrl': '/players/244298/yimmi-chara'},
#      'profileUrl': '/players/244298/yimmi-chara',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'ownGoal': None,
#      'suffix': None,
#      'isPenaltyShootoutEvent': False,
#      'nameStr': 'Yimmi Chara',
#      'firstName': 'Yimmi',
#      'lastName': 'Chara',
#      'playerId': 244298,
#      'newScore': [0, 1],
#      'penShootoutScore': None,
#      'assistStr': None,
#      'assistProfileUrl': None}]}}}

# %%
with open('json_data_old.json', 'w') as outfile:
    outfile.write(json.dumps(r.json()))
